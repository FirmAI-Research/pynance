# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from IPython.display import display_html
from itertools import chain,cycle
import yfinance as yf

def display_side_by_side(*args,titles=cycle([''])):
    html_str=''
    for df,title in zip(args, chain(titles,cycle(['</br>'])) ):
        html_str+='<th style="text-align:center"><td style="vertical-align:top">'
        html_str+=df.to_html().replace('table','table style="display:inline-block"')
        html_str+='</td></th>'
    display_html(html_str,raw=True)

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,6)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from lib.equity.fundamentals import Fundamentals, Ranks, DCF, Columns
from lib.equity.time_series import Technicals
from lib.equity.attribution import Attribution, FammaFrench, Brinson
from lib.fixed_income.rates import Treasuries
from lib.portfolio import drift_rebalancer as rebal
from lib.economy import activity as ecact

from calendar_dates import Calendar
cal = Calendar()
# Out:
# C:\dev\pynance\lib
# C:\dev\pynance\lib

# %% [markdown]
# # Attribution

# %% [markdown]
# What factors are driving broader market returns?

# %%
atr = Attribution()
holdings = atr.get_holdings('XLF') #SPY
returns = atr.get_portfolio_returns()
portf_returns = returns.resample('M').sum()
# Out:
# Extracting: https://www.zacks.com/funds/etf/XLF/holding
#
# 1 Failed download:
# - BRK.B: No data found, symbol may be delisted

# %% [markdown]
# ## Famma French

# %%
ff = FammaFrench(model = 'ThreeFactors', portf_rets = portf_returns)
print(ff.summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           portf_ex_rtn   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     36.93
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):           1.15e-07
# Time:                        18:09:15   Log-Likelihood:                -42.582
# No. Observations:                  21   AIC:                             93.16
# Df Residuals:                      17   BIC:                             97.34
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0375      0.478     -0.078      0.938      -1.046       0.971
# mkt           92.6178      9.076     10.205      0.000      73.470     111.766
# smb            8.0134     16.696      0.480      0.637     -27.213      43.240
# hml           47.5437      9.621      4.942      0.000      27.245      67.843
# ==============================================================================
# Omnibus:                        0.439   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.803   Jarque-Bera (JB):                0.561
# Skew:                           0.246   Prob(JB):                        0.756
# Kurtosis:                       2.368   Cond. No.                         38.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ff.plot()

# %%
ff = FammaFrench(model = 'IndustryFactors', portf_rets = portf_returns)
print(ff.summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              portf_rtn   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.947
# Method:                 Least Squares   F-statistic:                     37.04
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):           1.45e-06
# Time:                        18:09:16   Log-Likelihood:                -25.557
# No. Observations:                  21   AIC:                             73.11
# Df Residuals:                      10   BIC:                             84.60
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.1240      0.529      2.124      0.060      -0.055       2.303
# NoDur        -16.7711     16.597     -1.011      0.336     -53.751      20.208
# Durbl          7.2287      8.650      0.836      0.423     -12.044      26.502
# Manuf         -5.2989     20.720     -0.256      0.803     -51.467      40.869
# Enrgy         -6.3989      5.820     -1.099      0.297     -19.367       6.569
# HiTec         11.1318     17.637      0.631      0.542     -28.167      50.430
# Telcm         28.7651     17.482      1.645      0.131     -10.187      67.717
# Shops        -29.0693     15.618     -1.861      0.092     -63.868       5.729
# Hlth         -21.5697     11.512     -1.874      0.090     -47.219       4.080
# Utils         -0.3841     12.665     -0.030      0.976     -28.604      27.836
# Other        101.9759     16.266      6.269      0.000      65.734     138.218
# ==============================================================================
# Omnibus:                        1.721   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                1.130
# Skew:                           0.563   Prob(JB):                        0.568
# Kurtosis:                       2.848   Cond. No.                         114.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
ff.plot()

# %% [markdown]
# ## Brinson

# %%
...
# Out:
# Ellipsis

# %% [markdown]
# # Fundamentals

# %% [markdown]
# Fundamental Equity Analysis

# %%
ticker = ['JNJ']

# %%
rank = Ranks(ticker = ticker[0])
ranks = rank.get_ranks()

# %%
fun = Fundamentals( ticker = ticker)
fun

# %% [markdown]
# <strong>Left Frame:</strong> Values as reported (in Millions, USD)<br>
# <strong>Middle Frame:</strong> Percent Change <br>
# <strong>Right Frame:</strong> Percentile Rank vs. Industry Peers (Higher values are assigned a lower percentile rank)<br>

# %%
x = fun.get( columns = Columns.INCOME.value, limit = 5 ).style_jupyter(fun.df)
y = fun.percent_change().style_jupyter(fun.pct_chg, units = '%')
z = ranks.style_jupyter(cols = Columns.INCOME.value)

display_side_by_side(x, y, z)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_517ac_row0_col0, #T_517ac_row0_col1, #T_517ac_row0_col2, #T_517ac_row0_col3, #T_517ac_row0_col4, #T_517ac_row1_col0, #T_517ac_row1_col1, #T_517ac_row1_col2, #T_517ac_row1_col3, #T_517ac_row1_col4, #T_517ac_row2_col0, #T_517ac_row2_col1, #T_517ac_row2_col2, #T_517ac_row2_col3, #T_517ac_row2_col4, #T_517ac_row3_col0, #T_517ac_row3_col1, #T_517ac_row3_col2, #T_517ac_row3_col3, #T_517ac_row3_col4, #T_517ac_row4_col0, #T_517ac_row4_col1, #T_517ac_row4_col2, #T_517ac_row4_col3, #T_517ac_row4_col4, #T_517ac_row5_col0, #T_517ac_row5_col1, #T_517ac_row5_col2, #T_517ac_row5_col3, #T_517ac_row5_col4, #T_517ac_row6_col0, #T_517ac_row6_col1, #T_517ac_row6_col2, #T_517ac_row6_col3, #T_517ac_row6_col4, #T_517ac_row7_col0, #T_517ac_row7_col1, #T_517ac_row7_col2, #T_517ac_row7_col3, #T_517ac_row7_col4, #T_517ac_row8_col0, #T_517ac_row8_col1, #T_517ac_row8_col2, #T_517ac_row8_col3, #T_517ac_row8_col4 {
#   color: black;
# }
# </style>
# <table style="display:inline-block" id="T_517ac">
#   <thead>
#     <tr>
#       <th class="index_name level0" >calendardate</th>
#       <th id="T_517ac_level0_col0" class="col_heading level0 col0" >2021-09-30</th>
#       <th id="T_517ac_level0_col1" class="col_heading level0 col1" >2021-12-31</th>
#       <th id="T_517ac_level0_col2" class="col_heading level0 col2" >2022-03-31</th>
#       <th id="T_517ac_level0_col3" class="col_heading level0 col3" >2022-06-30</th>
#       <th id="T_517ac_level0_col4" class="col_heading level0 col4" >2022-09-30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_517ac_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_517ac_row0_col0" class="data row0 col0" >$23,338.0</td>
#       <td id="T_517ac_row0_col1" class="data row0 col1" >$24,804.0</td>
#       <td id="T_517ac_row0_col2" class="data row0 col2" >$23,426.0</td>
#       <td id="T_517ac_row0_col3" class="data row0 col3" >$24,020.0</td>
#       <td id="T_517ac_row0_col4" class="data row0 col4" >$23,791.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row1" class="row_heading level0 row1" >cogs</th>
#       <td id="T_517ac_row1_col0" class="data row1 col0" >$7,250.0</td>
#       <td id="T_517ac_row1_col1" class="data row1 col1" >$7,955.0</td>
#       <td id="T_517ac_row1_col2" class="data row1 col2" >$7,598.0</td>
#       <td id="T_517ac_row1_col3" class="data row1 col3" >$7,919.0</td>
#       <td id="T_517ac_row1_col4" class="data row1 col4" >$7,807.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row2" class="row_heading level0 row2" >gp</th>
#       <td id="T_517ac_row2_col0" class="data row2 col0" >$16,088.0</td>
#       <td id="T_517ac_row2_col1" class="data row2 col1" >$16,849.0</td>
#       <td id="T_517ac_row2_col2" class="data row2 col2" >$15,828.0</td>
#       <td id="T_517ac_row2_col3" class="data row2 col3" >$16,101.0</td>
#       <td id="T_517ac_row2_col4" class="data row2 col4" >$15,984.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row3" class="row_heading level0 row3" >opex</th>
#       <td id="T_517ac_row3_col0" class="data row3 col0" >$10,382.0</td>
#       <td id="T_517ac_row3_col1" class="data row3 col1" >$11,957.0</td>
#       <td id="T_517ac_row3_col2" class="data row3 col2" >$10,080.0</td>
#       <td id="T_517ac_row3_col3" class="data row3 col3" >$10,014.0</td>
#       <td id="T_517ac_row3_col4" class="data row3 col4" >$9,768.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row4" class="row_heading level0 row4" >opinc</th>
#       <td id="T_517ac_row4_col0" class="data row4 col0" >$5,706.0</td>
#       <td id="T_517ac_row4_col1" class="data row4 col1" >$4,892.0</td>
#       <td id="T_517ac_row4_col2" class="data row4 col2" >$5,748.0</td>
#       <td id="T_517ac_row4_col3" class="data row4 col3" >$6,087.0</td>
#       <td id="T_517ac_row4_col4" class="data row4 col4" >$6,216.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row5" class="row_heading level0 row5" >ebt</th>
#       <td id="T_517ac_row5_col0" class="data row5 col0" >$3,849.0</td>
#       <td id="T_517ac_row5_col1" class="data row5 col1" >$4,836.0</td>
#       <td id="T_517ac_row5_col2" class="data row5 col2" >$5,862.0</td>
#       <td id="T_517ac_row5_col3" class="data row5 col3" >$5,840.0</td>
#       <td id="T_517ac_row5_col4" class="data row5 col4" >$5,822.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row6" class="row_heading level0 row6" >netinc</th>
#       <td id="T_517ac_row6_col0" class="data row6 col0" >$3,667.0</td>
#       <td id="T_517ac_row6_col1" class="data row6 col1" >$4,736.0</td>
#       <td id="T_517ac_row6_col2" class="data row6 col2" >$5,149.0</td>
#       <td id="T_517ac_row6_col3" class="data row6 col3" >$4,814.0</td>
#       <td id="T_517ac_row6_col4" class="data row6 col4" >$4,458.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row7" class="row_heading level0 row7" >ebitda</th>
#       <td id="T_517ac_row7_col0" class="data row7 col0" >$5,683.0</td>
#       <td id="T_517ac_row7_col1" class="data row7 col1" >$6,739.0</td>
#       <td id="T_517ac_row7_col2" class="data row7 col2" >$7,641.0</td>
#       <td id="T_517ac_row7_col3" class="data row7 col3" >$7,622.0</td>
#       <td id="T_517ac_row7_col4" class="data row7 col4" >$7,558.0</td>
#     </tr>
#     <tr>
#       <th id="T_517ac_level0_row8" class="row_heading level0 row8" >depamor</th>
#       <td id="T_517ac_row8_col0" class="data row8 col0" >$1,814.0</td>
#       <td id="T_517ac_row8_col1" class="data row8 col1" >$1,843.0</td>
#       <td id="T_517ac_row8_col2" class="data row8 col2" >$1,769.0</td>
#       <td id="T_517ac_row8_col3" class="data row8 col3" >$1,744.0</td>
#       <td id="T_517ac_row8_col4" class="data row8 col4" >$1,685.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline-block">
# </td></th><th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_43fbd_row0_col0, #T_43fbd_row0_col1, #T_43fbd_row0_col3, #T_43fbd_row1_col0, #T_43fbd_row1_col1, #T_43fbd_row1_col3, #T_43fbd_row2_col0, #T_43fbd_row2_col1, #T_43fbd_row2_col3, #T_43fbd_row3_col0, #T_43fbd_row3_col1, #T_43fbd_row4_col0, #T_43fbd_row4_col2, #T_43fbd_row4_col3, #T_43fbd_row4_col4, #T_43fbd_row5_col0, #T_43fbd_row5_col1, #T_43fbd_row5_col2, #T_43fbd_row6_col0, #T_43fbd_row6_col1, #T_43fbd_row6_col2, #T_43fbd_row7_col0, #T_43fbd_row7_col1, #T_43fbd_row7_col2, #T_43fbd_row8_col0, #T_43fbd_row8_col1 {
#   color: black;
# }
# #T_43fbd_row0_col2, #T_43fbd_row0_col4, #T_43fbd_row1_col2, #T_43fbd_row1_col4, #T_43fbd_row2_col2, #T_43fbd_row2_col4, #T_43fbd_row3_col2, #T_43fbd_row3_col3, #T_43fbd_row3_col4, #T_43fbd_row4_col1, #T_43fbd_row5_col3, #T_43fbd_row5_col4, #T_43fbd_row6_col3, #T_43fbd_row6_col4, #T_43fbd_row7_col3, #T_43fbd_row7_col4, #T_43fbd_row8_col2, #T_43fbd_row8_col3, #T_43fbd_row8_col4 {
#   color: red;
# }
# </style>
# <table style="display:inline-block" id="T_43fbd">
#   <thead>
#     <tr>
#       <th class="index_name level0" >calendardate</th>
#       <th id="T_43fbd_level0_col0" class="col_heading level0 col0" >2021-09-30</th>
#       <th id="T_43fbd_level0_col1" class="col_heading level0 col1" >2021-12-31</th>
#       <th id="T_43fbd_level0_col2" class="col_heading level0 col2" >2022-03-31</th>
#       <th id="T_43fbd_level0_col3" class="col_heading level0 col3" >2022-06-30</th>
#       <th id="T_43fbd_level0_col4" class="col_heading level0 col4" >2022-09-30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43fbd_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_43fbd_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_43fbd_row0_col1" class="data row0 col1" >6.28%</td>
#       <td id="T_43fbd_row0_col2" class="data row0 col2" >-5.56%</td>
#       <td id="T_43fbd_row0_col3" class="data row0 col3" >2.54%</td>
#       <td id="T_43fbd_row0_col4" class="data row0 col4" >-0.95%</td>
#     </tr>
#     <tr>
#       <th id="T_43fbd_level0_row1" class="row_heading level0 row1" >cogs</th>
#       <td id="T_43fbd_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_43fbd_row1_col1" class="data row1 col1" >9.72%<

# %%
x = fun.get( columns = Columns.CASHFLOW.value, limit = 5 ).style_jupyter(fun.df)
y = fun.percent_change().style_jupyter(fun.pct_chg, units = '%')
z = ranks.style_jupyter(cols = Columns.CASHFLOW.value)

display_side_by_side(x, y, z)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_cb3d9_row0_col0, #T_cb3d9_row0_col1, #T_cb3d9_row0_col2, #T_cb3d9_row0_col3, #T_cb3d9_row0_col4, #T_cb3d9_row1_col0, #T_cb3d9_row1_col1, #T_cb3d9_row1_col2, #T_cb3d9_row1_col3, #T_cb3d9_row1_col4, #T_cb3d9_row2_col0, #T_cb3d9_row2_col1, #T_cb3d9_row2_col2, #T_cb3d9_row2_col3, #T_cb3d9_row2_col4, #T_cb3d9_row3_col0, #T_cb3d9_row3_col1, #T_cb3d9_row3_col2, #T_cb3d9_row3_col3, #T_cb3d9_row3_col4, #T_cb3d9_row4_col0, #T_cb3d9_row4_col1, #T_cb3d9_row4_col2, #T_cb3d9_row4_col3, #T_cb3d9_row4_col4, #T_cb3d9_row5_col0, #T_cb3d9_row5_col1, #T_cb3d9_row5_col2, #T_cb3d9_row5_col3, #T_cb3d9_row5_col4, #T_cb3d9_row6_col0, #T_cb3d9_row6_col1, #T_cb3d9_row6_col2, #T_cb3d9_row6_col3, #T_cb3d9_row6_col4, #T_cb3d9_row7_col0, #T_cb3d9_row7_col1, #T_cb3d9_row7_col2, #T_cb3d9_row7_col3, #T_cb3d9_row7_col4, #T_cb3d9_row8_col0, #T_cb3d9_row8_col4, #T_cb3d9_row12_col2, #T_cb3d9_row14_col0, #T_cb3d9_row14_col1, #T_cb3d9_row14_col2, #T_cb3d9_row14_col3, #T_cb3d9_row14_col4, #T_cb3d9_row15_col0, #T_cb3d9_row15_col3, #T_cb3d9_row15_col4 {
#   color: black;
# }
# #T_cb3d9_row8_col1, #T_cb3d9_row8_col2, #T_cb3d9_row8_col3, #T_cb3d9_row9_col0, #T_cb3d9_row9_col1, #T_cb3d9_row9_col2, #T_cb3d9_row9_col3, #T_cb3d9_row9_col4, #T_cb3d9_row10_col0, #T_cb3d9_row10_col1, #T_cb3d9_row10_col2, #T_cb3d9_row10_col3, #T_cb3d9_row10_col4, #T_cb3d9_row11_col0, #T_cb3d9_row11_col1, #T_cb3d9_row11_col2, #T_cb3d9_row11_col3, #T_cb3d9_row11_col4, #T_cb3d9_row12_col0, #T_cb3d9_row12_col1, #T_cb3d9_row12_col3, #T_cb3d9_row12_col4, #T_cb3d9_row13_col0, #T_cb3d9_row13_col1, #T_cb3d9_row13_col2, #T_cb3d9_row13_col3, #T_cb3d9_row13_col4, #T_cb3d9_row15_col1, #T_cb3d9_row15_col2 {
#   color: red;
# }
# </style>
# <table style="display:inline-block" id="T_cb3d9">
#   <thead>
#     <tr>
#       <th class="index_name level0" >calendardate</th>
#       <th id="T_cb3d9_level0_col0" class="col_heading level0 col0" >2021-09-30</th>
#       <th id="T_cb3d9_level0_col1" class="col_heading level0 col1" >2021-12-31</th>
#       <th id="T_cb3d9_level0_col2" class="col_heading level0 col2" >2022-03-31</th>
#       <th id="T_cb3d9_level0_col3" class="col_heading level0 col3" >2022-06-30</th>
#       <th id="T_cb3d9_level0_col4" class="col_heading level0 col4" >2022-09-30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb3d9_level0_row0" class="row_heading level0 row0" >cashneq</th>
#       <td id="T_cb3d9_row0_col0" class="data row0 col0" >$17,604.0</td>
#       <td id="T_cb3d9_row0_col1" class="data row0 col1" >$14,487.0</td>
#       <td id="T_cb3d9_row0_col2" class="data row0 col2" >$10,463.0</td>
#       <td id="T_cb3d9_row0_col3" class="data row0 col3" >$10,983.0</td>
#       <td id="T_cb3d9_row0_col4" class="data row0 col4" >$11,355.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row1" class="row_heading level0 row1" >netinc</th>
#       <td id="T_cb3d9_row1_col0" class="data row1 col0" >$3,667.0</td>
#       <td id="T_cb3d9_row1_col1" class="data row1 col1" >$4,736.0</td>
#       <td id="T_cb3d9_row1_col2" class="data row1 col2" >$5,149.0</td>
#       <td id="T_cb3d9_row1_col3" class="data row1 col3" >$4,814.0</td>
#       <td id="T_cb3d9_row1_col4" class="data row1 col4" >$4,458.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row2" class="row_heading level0 row2" >depamor</th>
#       <td id="T_cb3d9_row2_col0" class="data row2 col0" >$1,814.0</td>
#       <td id="T_cb3d9_row2_col1" class="data row2 col1" >$1,843.0</td>
#       <td id="T_cb3d9_row2_col2" class="data row2 col2" >$1,769.0</td>
#       <td id="T_cb3d9_row2_col3" class="data row2 col3" >$1,744.0</td>
#       <td id="T_cb3d9_row2_col4" class="data row2 col4" >$1,685.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row3" class="row_heading level0 row3" >opex</th>
#       <td id="T_cb3d9_row3_col0" class="data row3 col0" >$10,382.0</td>
#       <td id="T_cb3d9_row3_col1" class="data row3 col1" >$11,957.0</td>
#       <td id="T_cb3d9_row3_col2" class="data row3 col2" >$10,080.0</td>
#       <td id="T_cb3d9_row3_col3" class="data row3 col3" >$10,014.0</td>
#       <td id="T_cb3d9_row3_col4" class="data row3 col4" >$9,768.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row4" class="row_heading level0 row4" >receivables</th>
#       <td id="T_cb3d9_row4_col0" class="data row4 col0" >$14,911.0</td>
#       <td id="T_cb3d9_row4_col1" class="data row4 col1" >$15,283.0</td>
#       <td id="T_cb3d9_row4_col2" class="data row4 col2" >$15,594.0</td>
#       <td id="T_cb3d9_row4_col3" class="data row4 col3" >$16,139.0</td>
#       <td id="T_cb3d9_row4_col4" class="data row4 col4" >$15,890.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row5" class="row_heading level0 row5" >payables</th>
#       <td id="T_cb3d9_row5_col0" class="data row5 col0" >$8,961.0</td>
#       <td id="T_cb3d9_row5_col1" class="data row5 col1" >$11,055.0</td>
#       <td id="T_cb3d9_row5_col2" class="data row5 col2" >$9,309.0</td>
#       <td id="T_cb3d9_row5_col3" class="data row5 col3" >$9,765.0</td>
#       <td id="T_cb3d9_row5_col4" class="data row5 col4" >$10,153.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row6" class="row_heading level0 row6" >inventory</th>
#       <td id="T_cb3d9_row6_col0" class="data row6 col0" >$10,387.0</td>
#       <td id="T_cb3d9_row6_col1" class="data row6 col1" >$10,387.0</td>
#       <td id="T_cb3d9_row6_col2" class="data row6 col2" >$10,990.0</td>
#       <td id="T_cb3d9_row6_col3" class="data row6 col3" >$11,437.0</td>
#       <td id="T_cb3d9_row6_col4" class="data row6 col4" >$11,675.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row7" class="row_heading level0 row7" >ncfo</th>
#       <td id="T_cb3d9_row7_col0" class="data row7 col0" >$8,290.0</td>
#       <td id="T_cb3d9_row7_col1" class="data row7 col1" >$5,732.0</td>
#       <td id="T_cb3d9_row7_col2" class="data row7 col2" >$3,979.0</td>
#       <td id="T_cb3d9_row7_col3" class="data row7 col3" >$5,581.0</td>
#       <td id="T_cb3d9_row7_col4" class="data row7 col4" >$6,284.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row8" class="row_heading level0 row8" >ncfbus</th>
#       <td id="T_cb3d9_row8_col0" class="data row8 col0" >$12.0</td>
#       <td id="T_cb3d9_row8_col1" class="data row8 col1" >$-15.0</td>
#       <td id="T_cb3d9_row8_col2" class="data row8 col2" >$-4.0</td>
#       <td id="T_cb3d9_row8_col3" class="data row8 col3" >$-205.0</td>
#       <td id="T_cb3d9_row8_col4" class="data row8 col4" >$9.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row9" class="row_heading level0 row9" >ncfi</th>
#       <td id="T_cb3d9_row9_col0" class="data row9 col0" >$-2,719.0</td>
#       <td id="T_cb3d9_row9_col1" class="data row9 col1" >$-5,360.0</td>
#       <td id="T_cb3d9_row9_col2" class="data row9 col2" >$-3,634.0</td>
#       <td id="T_cb3d9_row9_col3" class="data row9 col3" >$-2,639.0</td>
#       <td id="T_cb3d9_row9_col4" class="data row9 col4" >$-1,701.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row10" class="row_heading level0 row10" >ncfinv</th>
#       <td id="T_cb3d9_row10_col0" class="data row10 col0" >$-1,968.0</td>
#       <td id="T_cb3d9_row10_col1" class="data row10 col1" >$-3,836.0</td>
#       <td id="T_cb3d9_row10_col2" class="data row10 col2" >$-2,964.0</td>
#       <td id="T_cb3d9_row10_col3" class="data row10 col3" >$-1,460.0</td>
#       <td id="T_cb3d9_row10_col4" class="data row10 col4" >$-720.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row11" class="row_heading level0 row11" >ncfdiv</th>
#       <td id="T_cb3d9_row11_col0" class="data row11 col0" >$-2,791.0</td>
#       <td id="T_cb3d9_row11_col1" class="data row11 col1" >$-2,791.0</td>
#       <td id="T_cb3d9_row11_col2" class="data row11 col2" >$-2,787.0</td>
#       <td id="T_cb3d9_row11_col3" class="data row11 col3" >$-2,971.0</td>
#       <td id="T_cb3d9_row11_col4" class="data row11 col4" >$-2,970.0</td>
#     </tr>
#     <tr>
#       <th id="T_cb3d9_level0_row12" class="row_heading level0 row12" >ncfx</th>
#       <td id="T_cb3d9_row12_col0" class="data row12 col0" >$-92.0</td>

# %%
x = fun.get( columns = Columns.BALANCE.value, limit = 5 ).style_jupyter(fun.df)
y = fun.percent_change().style_jupyter(fun.pct_chg, units = '%')
z = ranks.style_jupyter(cols = Columns.BALANCE.value)

display_side_by_side(x, y, z)
# Out:
# <th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_0460d_row0_col0, #T_0460d_row0_col1, #T_0460d_row0_col2, #T_0460d_row0_col3, #T_0460d_row0_col4, #T_0460d_row1_col0, #T_0460d_row1_col1, #T_0460d_row1_col2, #T_0460d_row1_col3, #T_0460d_row1_col4, #T_0460d_row2_col0, #T_0460d_row2_col1, #T_0460d_row2_col2, #T_0460d_row2_col3, #T_0460d_row2_col4, #T_0460d_row3_col0, #T_0460d_row3_col1, #T_0460d_row3_col2, #T_0460d_row3_col3, #T_0460d_row3_col4, #T_0460d_row4_col0, #T_0460d_row4_col1, #T_0460d_row4_col2, #T_0460d_row4_col3, #T_0460d_row4_col4, #T_0460d_row5_col0, #T_0460d_row5_col1, #T_0460d_row5_col2, #T_0460d_row5_col3, #T_0460d_row5_col4, #T_0460d_row6_col0, #T_0460d_row6_col1, #T_0460d_row6_col2, #T_0460d_row6_col3, #T_0460d_row6_col4, #T_0460d_row7_col0, #T_0460d_row7_col1, #T_0460d_row7_col2, #T_0460d_row7_col3, #T_0460d_row7_col4, #T_0460d_row8_col0, #T_0460d_row8_col1, #T_0460d_row8_col2, #T_0460d_row8_col3, #T_0460d_row8_col4, #T_0460d_row9_col0, #T_0460d_row9_col1, #T_0460d_row9_col2, #T_0460d_row9_col3, #T_0460d_row9_col4, #T_0460d_row10_col0, #T_0460d_row10_col1, #T_0460d_row10_col2, #T_0460d_row10_col3, #T_0460d_row10_col4 {
#   color: black;
# }
# </style>
# <table style="display:inline-block" id="T_0460d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >calendardate</th>
#       <th id="T_0460d_level0_col0" class="col_heading level0 col0" >2021-09-30</th>
#       <th id="T_0460d_level0_col1" class="col_heading level0 col1" >2021-12-31</th>
#       <th id="T_0460d_level0_col2" class="col_heading level0 col2" >2022-03-31</th>
#       <th id="T_0460d_level0_col3" class="col_heading level0 col3" >2022-06-30</th>
#       <th id="T_0460d_level0_col4" class="col_heading level0 col4" >2022-09-30</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0460d_level0_row0" class="row_heading level0 row0" >assetsc</th>
#       <td id="T_0460d_row0_col0" class="data row0 col0" >$59,889.0</td>
#       <td id="T_0460d_row0_col1" class="data row0 col1" >$60,979.0</td>
#       <td id="T_0460d_row0_col2" class="data row0 col2" >$60,424.0</td>
#       <td id="T_0460d_row0_col3" class="data row0 col3" >$63,847.0</td>
#       <td id="T_0460d_row0_col4" class="data row0 col4" >$65,236.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row1" class="row_heading level0 row1" >assetsnc</th>
#       <td id="T_0460d_row1_col0" class="data row1 col0" >$119,339.0</td>
#       <td id="T_0460d_row1_col1" class="data row1 col1" >$121,039.0</td>
#       <td id="T_0460d_row1_col2" class="data row1 col2" >$117,931.0</td>
#       <td id="T_0460d_row1_col3" class="data row1 col3" >$113,877.0</td>
#       <td id="T_0460d_row1_col4" class="data row1 col4" >$109,888.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row2" class="row_heading level0 row2" >receivables</th>
#       <td id="T_0460d_row2_col0" class="data row2 col0" >$14,911.0</td>
#       <td id="T_0460d_row2_col1" class="data row2 col1" >$15,283.0</td>
#       <td id="T_0460d_row2_col2" class="data row2 col2" >$15,594.0</td>
#       <td id="T_0460d_row2_col3" class="data row2 col3" >$16,139.0</td>
#       <td id="T_0460d_row2_col4" class="data row2 col4" >$15,890.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row3" class="row_heading level0 row3" >inventory</th>
#       <td id="T_0460d_row3_col0" class="data row3 col0" >$10,387.0</td>
#       <td id="T_0460d_row3_col1" class="data row3 col1" >$10,387.0</td>
#       <td id="T_0460d_row3_col2" class="data row3 col2" >$10,990.0</td>
#       <td id="T_0460d_row3_col3" class="data row3 col3" >$11,437.0</td>
#       <td id="T_0460d_row3_col4" class="data row3 col4" >$11,675.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row4" class="row_heading level0 row4" >assets</th>
#       <td id="T_0460d_row4_col0" class="data row4 col0" >$179,228.0</td>
#       <td id="T_0460d_row4_col1" class="data row4 col1" >$182,018.0</td>
#       <td id="T_0460d_row4_col2" class="data row4 col2" >$178,355.0</td>
#       <td id="T_0460d_row4_col3" class="data row4 col3" >$177,724.0</td>
#       <td id="T_0460d_row4_col4" class="data row4 col4" >$175,124.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row5" class="row_heading level0 row5" >liabilitiesc</th>
#       <td id="T_0460d_row5_col0" class="data row5 col0" >$44,561.0</td>
#       <td id="T_0460d_row5_col1" class="data row5 col1" >$45,226.0</td>
#       <td id="T_0460d_row5_col2" class="data row5 col2" >$43,390.0</td>
#       <td id="T_0460d_row5_col3" class="data row5 col3" >$44,821.0</td>
#       <td id="T_0460d_row5_col4" class="data row5 col4" >$45,543.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row6" class="row_heading level0 row6" >liabilitiesnc</th>
#       <td id="T_0460d_row6_col0" class="data row6 col0" >$64,395.0</td>
#       <td id="T_0460d_row6_col1" class="data row6 col1" >$62,769.0</td>
#       <td id="T_0460d_row6_col2" class="data row6 col2" >$60,256.0</td>
#       <td id="T_0460d_row6_col3" class="data row6 col3" >$56,546.0</td>
#       <td id="T_0460d_row6_col4" class="data row6 col4" >$54,982.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row7" class="row_heading level0 row7" >payables</th>
#       <td id="T_0460d_row7_col0" class="data row7 col0" >$8,961.0</td>
#       <td id="T_0460d_row7_col1" class="data row7 col1" >$11,055.0</td>
#       <td id="T_0460d_row7_col2" class="data row7 col2" >$9,309.0</td>
#       <td id="T_0460d_row7_col3" class="data row7 col3" >$9,765.0</td>
#       <td id="T_0460d_row7_col4" class="data row7 col4" >$10,153.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row8" class="row_heading level0 row8" >debt</th>
#       <td id="T_0460d_row8_col0" class="data row8 col0" >$33,928.0</td>
#       <td id="T_0460d_row8_col1" class="data row8 col1" >$33,751.0</td>
#       <td id="T_0460d_row8_col2" class="data row8 col2" >$33,148.0</td>
#       <td id="T_0460d_row8_col3" class="data row8 col3" >$32,597.0</td>
#       <td id="T_0460d_row8_col4" class="data row8 col4" >$32,027.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row9" class="row_heading level0 row9" >equity</th>
#       <td id="T_0460d_row9_col0" class="data row9 col0" >$70,272.0</td>
#       <td id="T_0460d_row9_col1" class="data row9 col1" >$74,023.0</td>
#       <td id="T_0460d_row9_col2" class="data row9 col2" >$74,709.0</td>
#       <td id="T_0460d_row9_col3" class="data row9 col3" >$76,357.0</td>
#       <td id="T_0460d_row9_col4" class="data row9 col4" >$74,599.0</td>
#     </tr>
#     <tr>
#       <th id="T_0460d_level0_row10" class="row_heading level0 row10" >retearn</th>
#       <td id="T_0460d_row10_col0" class="data row10 col0" >$121,092.0</td>
#       <td id="T_0460d_row10_col1" class="data row10 col1" >$123,060.0</td>
#       <td id="T_0460d_row10_col2" class="data row10 col2" >$124,380.0</td>
#       <td id="T_0460d_row10_col3" class="data row10 col3" >$126,216.0</td>
#       <td id="T_0460d_row10_col4" class="data row10 col4" >$127,917.0</td>
#     </tr>
#   </tbody>
# </table style="display:inline-block">
# </td></th><th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_fff23_row0_col0, #T_fff23_row0_col1, #T_fff23_row0_col3, #T_fff23_row0_col4, #T_fff23_row1_col0, #T_fff23_row1_col1, #T_fff23_row2_col0, #T_fff23_row2_col1, #T_fff23_row2_col2, #T_fff23_row2_col3, #T_fff23_row3_col0, #T_fff23_row3_col1, #T_fff23_row3_col2, #T_fff23_row3_col3, #T_fff23_row3_col4, #T_fff23_row4_col0, #T_fff23_row4_col1, #T_fff23_row5_col0, #T_fff23_row5_col1, #T_fff23_row5_col3, #T_fff23_row5_col4, #T_fff23_row6_col0, #T_fff23_row7_col0, #T_fff23_row7_col1, #T_fff23_row7_col3, #T_fff23_row7_col4, #T_fff23_row8_col0, #T_fff23_row9_col0, #T_fff23_row9_col1, #T_fff23_row9_col2, #T_fff23_row9_col3, #T_fff23_row10_col0, #T_fff23_row10_col1, #T_fff23_row10_col2, #T_fff23_row10_col3, #T_fff23_row10_col4 {
#   color: black;
# }
# #T_fff23_row0_col2, #T_fff23_row1_col2, #T_fff23_row1_col3, #T_fff23_row1_col4, #T_fff23_row2_col4, #T_fff23_row4_col2, #T_fff23_row4_col3, #T_fff23_row4_col4, #T_fff23_row5_col2, #T_fff23_row6_col1, #T_fff23_row6_col2, #

# %% [markdown]
# ## Peers

# %% [markdown]
# Selected ticker vs Industry Peers

# %%
rank.plot_dual_axis_ranks(fun, cols = ['ticker', 'calendardate','pe','eps','roe','roc','grossmargin', 'oppmargin','fcfmargin'])
# Out:
# Drug Manufacturers - General

# %%
fun.plot_box_plot(cols = ['pe','eps','roe','roc','grossmargin', 'oppmargin','fcfmargin'])
# Out:
# Drug Manufacturers - General

# %%
peers = fun.get_peers()
fun = Fundamentals(ticker = peers)
print(fun)

x = fun.get( columns = Columns.INCOME.value, limit = 5 ).style_jupyter(fun.df)
y = fun.get( columns = Columns.PEERS.value, limit = 5 ).style_jupyter(fun.df, units = '%')
z = fun.get( columns = Columns.CASHFLOW_.value, limit = 5 ).style_jupyter(fun.df)

display_side_by_side(x,y,z)
# Out:
# Drug Manufacturers - General
# Fundamentals:Object:['JNJ', 'PFE', 'MRK', 'ABBV']
# <th style="text-align:center"><td style="vertical-align:top"><style type="text/css">
# #T_cd97f td {
#   border: 1px solid lightgrey !important;
# }
# #T_cd97f  th {
#   border: 1px solid lightgrey !important;
# }
# #T_cd97f_row0_col0, #T_cd97f_row0_col1, #T_cd97f_row0_col2, #T_cd97f_row0_col3, #T_cd97f_row0_col4, #T_cd97f_row1_col0, #T_cd97f_row1_col1, #T_cd97f_row1_col2, #T_cd97f_row1_col3, #T_cd97f_row1_col4, #T_cd97f_row2_col0, #T_cd97f_row2_col1, #T_cd97f_row2_col2, #T_cd97f_row2_col3, #T_cd97f_row2_col4, #T_cd97f_row3_col0, #T_cd97f_row3_col1, #T_cd97f_row3_col2, #T_cd97f_row3_col3, #T_cd97f_row3_col4, #T_cd97f_row4_col0, #T_cd97f_row4_col1, #T_cd97f_row4_col2, #T_cd97f_row4_col3, #T_cd97f_row4_col4, #T_cd97f_row5_col0, #T_cd97f_row5_col1, #T_cd97f_row5_col2, #T_cd97f_row5_col3, #T_cd97f_row5_col4, #T_cd97f_row6_col0, #T_cd97f_row6_col1, #T_cd97f_row6_col2, #T_cd97f_row6_col3, #T_cd97f_row6_col4, #T_cd97f_row7_col0, #T_cd97f_row7_col1, #T_cd97f_row7_col2, #T_cd97f_row7_col3, #T_cd97f_row7_col4, #T_cd97f_row8_col0, #T_cd97f_row8_col1, #T_cd97f_row8_col2, #T_cd97f_row8_col3, #T_cd97f_row8_col4, #T_cd97f_row9_col0, #T_cd97f_row9_col1, #T_cd97f_row9_col2, #T_cd97f_row9_col3, #T_cd97f_row9_col4, #T_cd97f_row10_col0, #T_cd97f_row10_col1, #T_cd97f_row10_col2, #T_cd97f_row10_col3, #T_cd97f_row10_col4, #T_cd97f_row11_col0, #T_cd97f_row11_col1, #T_cd97f_row11_col2, #T_cd97f_row11_col3, #T_cd97f_row11_col4, #T_cd97f_row12_col0, #T_cd97f_row12_col1, #T_cd97f_row12_col2, #T_cd97f_row12_col3, #T_cd97f_row12_col4, #T_cd97f_row13_col0, #T_cd97f_row13_col1, #T_cd97f_row13_col2, #T_cd97f_row13_col3, #T_cd97f_row13_col4, #T_cd97f_row14_col0, #T_cd97f_row14_col1, #T_cd97f_row14_col2, #T_cd97f_row14_col3, #T_cd97f_row14_col4, #T_cd97f_row15_col0, #T_cd97f_row15_col1, #T_cd97f_row15_col2, #T_cd97f_row15_col3, #T_cd97f_row15_col4, #T_cd97f_row16_col0, #T_cd97f_row16_col1, #T_cd97f_row16_col2, #T_cd97f_row16_col3, #T_cd97f_row16_col4, #T_cd97f_row17_col0, #T_cd97f_row17_col1, #T_cd97f_row17_col2, #T_cd97f_row17_col3, #T_cd97f_row17_col4, #T_cd97f_row18_col0, #T_cd97f_row18_col1, #T_cd97f_row18_col2, #T_cd97f_row18_col3, #T_cd97f_row18_col4, #T_cd97f_row19_col0, #T_cd97f_row19_col1, #T_cd97f_row19_col2, #T_cd97f_row19_col3, #T_cd97f_row19_col4, #T_cd97f_row20_col0, #T_cd97f_row20_col1, #T_cd97f_row20_col2, #T_cd97f_row20_col3, #T_cd97f_row20_col4, #T_cd97f_row21_col0, #T_cd97f_row21_col1, #T_cd97f_row21_col2, #T_cd97f_row21_col3, #T_cd97f_row21_col4, #T_cd97f_row22_col0, #T_cd97f_row22_col1, #T_cd97f_row22_col2, #T_cd97f_row22_col3, #T_cd97f_row22_col4, #T_cd97f_row23_col0, #T_cd97f_row23_col1, #T_cd97f_row23_col2, #T_cd97f_row23_col3, #T_cd97f_row23_col4, #T_cd97f_row24_col0, #T_cd97f_row24_col1, #T_cd97f_row24_col2, #T_cd97f_row24_col3, #T_cd97f_row24_col4, #T_cd97f_row25_col0, #T_cd97f_row25_col1, #T_cd97f_row25_col2, #T_cd97f_row25_col3, #T_cd97f_row25_col4, #T_cd97f_row26_col0, #T_cd97f_row26_col1, #T_cd97f_row26_col2, #T_cd97f_row26_col3, #T_cd97f_row26_col4, #T_cd97f_row27_col0, #T_cd97f_row27_col1, #T_cd97f_row27_col2, #T_cd97f_row27_col3, #T_cd97f_row27_col4, #T_cd97f_row28_col0, #T_cd97f_row28_col1, #T_cd97f_row28_col2, #T_cd97f_row28_col3, #T_cd97f_row28_col4, #T_cd97f_row29_col0, #T_cd97f_row29_col1, #T_cd97f_row29_col2, #T_cd97f_row29_col3, #T_cd97f_row29_col4, #T_cd97f_row30_col0, #T_cd97f_row30_col1, #T_cd97f_row30_col2, #T_cd97f_row30_col3, #T_cd97f_row30_col4, #T_cd97f_row31_col0, #T_cd97f_row31_col1, #T_cd97f_row31_col2, #T_cd97f_row31_col3, #T_cd97f_row31_col4, #T_cd97f_row32_col0, #T_cd97f_row32_col1, #T_cd97f_row32_col2, #T_cd97f_row32_col3, #T_cd97f_row32_col4, #T_cd97f_row33_col0, #T_cd97f_row33_col1, #T_cd97f_row33_col2, #T_cd97f_row33_col3, #T_cd97f_row33_col4, #T_cd97f_row34_col0, #T_cd97f_row34_col1, #T_cd97f_row34_col2, #T_cd97f_row34_col3, #T_cd97f_row34_col4, #T_cd97f_row35_col0, #T_cd97f_row35_col1, #T_cd97f_row35_col2, #T_cd97f_row35_col3, #T_cd97f_row35_col4 {
#   color: black;
#   border: 1px solid lightgrey;
# }
# </style>
# <table style="display:inline-block" id="T_cd97f">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >calendardate</th>
#       <th id="T_cd97f_level0_col0" class="col_heading level0 col0" >2021-09-30</th>
#       <th id="T_cd97f_level0_col1" class="col_heading level0 col1" >2021-12-31</th>
#       <th id="T_cd97f_level0_col2" class="col_heading level0 col2" >2022-03-31</th>
#       <th id="T_cd97f_level0_col3" class="col_heading level0 col3" >2022-06-30</th>
#       <th id="T_cd97f_level0_col4" class="col_heading level0 col4" >2022-09-30</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >&nbsp;</th>
#       <th class="index_name level1" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd97f_level0_row0" class="row_heading level0 row0" rowspan="4">revenue</th>
#       <th id="T_cd97f_level1_row0" class="row_heading level1 row0" >ABBV</th>
#       <td id="T_cd97f_row0_col0" class="data row0 col0" >$14,342</td>
#       <td id="T_cd97f_row0_col1" class="data row0 col1" >$14,886</td>
#       <td id="T_cd97f_row0_col2" class="data row0 col2" >$13,538</td>
#       <td id="T_cd97f_row0_col3" class="data row0 col3" >$14,583</td>
#       <td id="T_cd97f_row0_col4" class="data row0 col4" >$nan</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level1_row1" class="row_heading level1 row1" >JNJ</th>
#       <td id="T_cd97f_row1_col0" class="data row1 col0" >$23,338</td>
#       <td id="T_cd97f_row1_col1" class="data row1 col1" >$24,804</td>
#       <td id="T_cd97f_row1_col2" class="data row1 col2" >$23,426</td>
#       <td id="T_cd97f_row1_col3" class="data row1 col3" >$24,020</td>
#       <td id="T_cd97f_row1_col4" class="data row1 col4" >$23,791</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level1_row2" class="row_heading level1 row2" >MRK</th>
#       <td id="T_cd97f_row2_col0" class="data row2 col0" >$13,154</td>
#       <td id="T_cd97f_row2_col1" class="data row2 col1" >$13,521</td>
#       <td id="T_cd97f_row2_col2" class="data row2 col2" >$15,901</td>
#       <td id="T_cd97f_row2_col3" class="data row2 col3" >$14,593</td>
#       <td id="T_cd97f_row2_col4" class="data row2 col4" >$nan</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level1_row3" class="row_heading level1 row3" >PFE</th>
#       <td id="T_cd97f_row3_col0" class="data row3 col0" >$24,094</td>
#       <td id="T_cd97f_row3_col1" class="data row3 col1" >$23,635</td>
#       <td id="T_cd97f_row3_col2" class="data row3 col2" >$25,661</td>
#       <td id="T_cd97f_row3_col3" class="data row3 col3" >$27,742</td>
#       <td id="T_cd97f_row3_col4" class="data row3 col4" >$nan</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level0_row4" class="row_heading level0 row4" rowspan="4">cogs</th>
#       <th id="T_cd97f_level1_row4" class="row_heading level1 row4" >ABBV</th>
#       <td id="T_cd97f_row4_col0" class="data row4 col0" >$4,390</td>
#       <td id="T_cd97f_row4_col1" class="data row4 col1" >$4,320</td>
#       <td id="T_cd97f_row4_col2" class="data row4 col2" >$4,052</td>
#       <td id="T_cd97f_row4_col3" class="data row4 col3" >$4,170</td>
#       <td id="T_cd97f_row4_col4" class="data row4 col4" >$nan</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level1_row5" class="row_heading level1 row5" >JNJ</th>
#       <td id="T_cd97f_row5_col0" class="data row5 col0" >$7,250</td>
#       <td id="T_cd97f_row5_col1" class="data row5 col1" >$7,955</td>
#       <td id="T_cd97f_row5_col2" class="data row5 col2" >$7,598</td>
#       <td id="T_cd97f_row5_col3" class="data row5 col3" >$7,919</td>
#       <td id="T_cd97f_row5_col4" class="data row5 col4" >$7,807</td>
#     </tr>
#     <tr>
#       <th id="T_cd97f_level1_row6" class="row_heading level1 row6" >MRK</th>
#       <td id="T_cd97f_row6_col0" class="data row6 col0" >$3,450</td>
#       <td id="T_cd97f_row6_col1" class="data row6 col1" >$3,874</td>
#       <t

# %% [markdown]
# ## DCF

# %%
fun = Fundamentals( ticker = ticker)

# %% [markdown]
# ## Base Case

# %%
dcf = DCF(ticker=ticker, REV_GROWTH=0.025)
dcf.forecast_cf_from_opperations()
dcf.discount(ERM = 0.04, RFR = 0)
dcf.terminal_value(TERMINAL_GROWTH=0.05)
dcf.estimate_price_per_share()
# Out:
# [*********************100%***********************]  2 of 2 completed
# beta:  1.009980846223882
# wacc:  0.028522826035548548
# npv:  23785729439.806515
# terminal value:  173923379504.01547
# pv future cash flows:  75.1980149094446

# %% [markdown]
# ## Bull

# %%
dcf = DCF(ticker=ticker, REV_GROWTH=0.06)
dcf.forecast_cf_from_opperations()
dcf.discount(ERM = 0.04, RFR = 0)
dcf.terminal_value(TERMINAL_GROWTH=0.06)
dcf.estimate_price_per_share()
# Out:
# [*********************100%***********************]  2 of 2 completed
# beta:  1.0099820008574472
# wacc:  0.02858663366220043
# npv:  26326700815.80286
# terminal value:  207160189748.7472
# pv future cash flows:  88.80597748696464

# %% [markdown]
# ## Bear

# %%
dcf = DCF(ticker=ticker, REV_GROWTH=0.01)
dcf.forecast_cf_from_opperations()
dcf.discount(ERM = 0.04, RFR = 0)
dcf.terminal_value(TERMINAL_GROWTH=0.02)
dcf.estimate_price_per_share()
# Out:
# [*********************100%***********************]  2 of 2 completed
# beta:  1.0099808294502581
# wacc:  0.02849802367898485
# npv:  22765011621.113434
# terminal value:  157099962772.5339
# pv future cash flows:  68.41105651830924

# %% [markdown]
# # Technicals

# %%
tech = Technicals()

# %%
tech.ta_dashboard(fun)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Adj Close    174.869995
# Name: 2022-10-28 00:00:00, dtype: float64

# %% [markdown]
# # Rates

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,6)

# %%
ust = Treasuries(years = ['2021', '2022'])

# %%
ust.df.tail()
# Out:
#             1 Month  2 Month  3 Month  6 Month  1 Year  2 Year  3 Year  \
# date
# 2022-10-28     3.75     3.95     4.18     4.51    4.55    4.41    4.38
# 2022-10-31     3.73     4.00     4.22     4.57    4.66    4.51    4.45
# 2022-11-01     3.72     4.00     4.23     4.58    4.75    4.54    4.48
# 2022-11-02     3.70     4.01     4.22     4.57    4.76    4.61    4.54
# 2022-11-03     3.75     4.04     4.25     4.57    4.78    4.71    4.63
#
#             5 Year  7 Year  10 Year  20 Year  30 Year
# date
# 2022-10-28    4.19    4.10     4.02     4.38     4.15
# 2022-10-31    4.27    4.18     4.10     4.44     4.22
# 2022-11-01    4.27    4.18     4.07     4.37     4.14
# 2022-11-02    4.30    4.20     4.10     4.41     4.15
# 2022-11-03    4.36    4.26     4.14     4.42     4.18

# %%
ust.rates_map()

# %%
ust.rates_change_map()

# %%
ust.change_since()
# Out:
#               1 Month  2 Month  3 Month  6 Month  1 Year  2 Year  3 Year  \
# Change Since
# 60 days          1.51     1.61     1.60     1.44    1.52    1.48    1.50
# 20 days          0.70     0.70     0.79     0.53    0.59    0.48    0.39
# 10 days          0.20     0.26     0.16     0.14    0.20    0.22    0.11
# 5 days           0.00     0.09     0.07     0.06    0.23    0.30    0.25
#
#               5 Year  7 Year  10 Year  20 Year  30 Year
# Change Since
# 60 days         1.43    1.40     1.36     1.15     1.14
# 20 days         0.31    0.31     0.31     0.34     0.37
# 10 days         0.02   -0.02    -0.07    -0.12    -0.15
# 5 days          0.17    0.16     0.12     0.04     0.03

# %% [markdown]
# ## Bootstrapping spot rates

# %%
zeroes, forwards = ust.build_zero_curve()
# Out:
# [3.7053351  4.06422235 4.31424086 4.59397626 4.69669859 4.67394378
#  4.56249779 4.45124313 4.35952593 4.28741949 4.23092794 4.14996877]

# %%
zeroes
# Out:
# array([3.71998266, 4.04779198, 4.29294949, 4.59597502, 4.72638458,
#        4.71470339, 4.56844468, 4.41725594, 4.30561334, 4.24076445,
#        4.21583123, 4.24430324])

# %%
forwards
# Out:
# array([4.47030879, 4.89860172, 5.13031575, 5.20613917, 5.00003164,
#        4.38064012, 3.92422404, 3.74396911, 3.77894728, 3.93817559,
#        4.14818221, 4.55406933])

# %%
data = yf.download(f"TLT AGG BND SPY", start="2015-01-01", end=cal.today())['Adj Close']
ust.market_correlations(data, title = 'Stock/Bond Correlation')
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
ust.stock_bond_correlation()
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
ust.stock_treasury_correlation()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ust.tens_twos_spread()

# %%
ust.breakeven_inflation()

# %%
ust.expected_inflation()

# %%
ust.credit_spreads()

# %% [markdown]
# # Economic Activity

# %%
ecact.inflation()

# %%
ecact.consumer_sentiment()

# %%
ecact.fomc_projections()

# %%
ecact.industrial_prod()

# %%
ecact.corporate_profits()

# %%
ecact.gdp()

# %%
ecact.spy_and_vol()

# %% [markdown]
# # Rebalance

# %%
# portfolio targets "t"
columns_t = ['ticker','allocation_target','assetclass']
positions_t = [
    ['SPY',0.1,'ETF'],
    ['IWM',0.1,'ETF'],
    ['QQQ',0.1,'ETF'],
    ['XLF',0.1,'ETF'],
    ['XLI',0.1,'ETF'],
    ['EEM',0.1,'ETF'],
    ['XLV',0.1,'ETF'],
    ['IAU',0.1,'ETF'],
    ['TLT',0.1,'ETF'],
    ['SHV',0.05,'ETF'],
    ['HYG',0.05,'ETF'],
    ]

# portfolio current holdings "c"
columns_c = ['accounttype','accountid','lastrebaldate','ticker','assetclass','basisdate','costbasis','shares']
positions_c = [     ['IRA','0001','2020-11-16','SPY','ETF','2018-11-16', 260   ,913.483],    # traditional ira   
                    ['IRA','0001','2020-11-16','QQQ','ETF','2018-11-16', 175  ,514.298],
                    ['IRA','0001','2020-11-16','XLF','ETF','2018-11-16',  27  ,151.121],

                    ['401K','0002','2020-11-16','SPY','ETF','2018-11-16',  260  ,772.407],    # 401k
                    ['401K','0002','2020-11-16','IWM','ETF','2018-11-16',  157  ,151.578],

                    ['IRA','0003','2020-11-16','HYG','ETF','2018-11-16', 85   ,3.14],         # roth
                    ['IRA','0003','2020-11-16','IAU','ETF','2018-11-16',  18   ,549.871]        
              ]

# %%
tickers, targetalloc, start_port, agg_port = rebal.build_initial_portfolios(columns_t, positions_t, columns_c, positions_c)

# %%
ohlc = rebal.retrieve_latest_security_price(tickers)
ohlc = ohlc.to_frame(name='close').reset_index(level=1, drop=True)
# Out:
# ...retrieving current market price data...
# Tickers Not Found:  []

# %%
final_port = rebal.build_initial_drift_df(agg_port, targetalloc, ohlc)
final_port.head()
# Out:
#   ticker lastrebaldate assetclass  basisdate  costbasis    shares  \
# 0    HYG    2020-11-16        ETF 2018-11-16       85.0     3.140
# 1    IAU    2020-11-16        ETF 2018-11-16       18.0   549.871
# 2    IWM    2020-11-16        ETF 2018-11-16      157.0   151.578
# 3    QQQ    2020-11-16        ETF 2018-11-16      175.0   514.298
# 4    SPY    2020-11-16        ETF 2018-11-16      260.0  1685.890
#
#    allocation_target   close         value  allocation  correction  \
# 0               0.05   72.40     227.33600    0.000281    0.049719
# 1               0.10   30.96   17024.00616    0.021057    0.078943
# 2               0.10  176.30   26723.20140    0.033055    0.066945
# 3               0.10  260.49  133969.48602    0.165710   -0.065710
# 4               0.10  371.01  625482.04890    0.773673   -0.673673
#
#    new_money_in
# 0          50.0
# 1         100.0
# 2         100.0
# 3         100.0
# 4         100.0

# %%
rebal_port, stable_port = rebal.build_initial_order_df(final_port)

# %%
rebal_port.head()
# Out:
#   ticker lastrebaldate assetclass  basisdate  costbasis    shares  \
# 0    HYG    2020-11-16        ETF 2018-11-16       85.0     3.140
# 1    IAU    2020-11-16        ETF 2018-11-16       18.0   549.871
# 2    IWM    2020-11-16        ETF 2018-11-16      157.0   151.578
# 3    QQQ    2020-11-16        ETF 2018-11-16      175.0   514.298
# 4    SPY    2020-11-16        ETF 2018-11-16      260.0  1685.890
#
#    allocation_target   close         value  allocation  ...  rebal_flag_time  \
# 0               0.05   72.40     227.33600    0.000281  ...                0
# 1               0.10   30.96   17024.00616    0.021057  ...                0
# 2               0.10  176.30   26723.20140    0.033055  ...                0
# 3               0.10  260.49  133969.48602    0.165710  ...                0
# 4               0.10  371.01  625482.04890    0.773673  ...                0
#
#    rebal_flag_exit  rebal_flag_newmoney  rebal_flag      value_chg  \
# 0                0                    1           1   40245.584389
# 1                0                    1           1   63921.834618
# 2                0                    1           1   54222.639378
# 3                0                    1           1  -53023.645242
# 4                0                    1           1 -544536.208122
#
#     shares_chg  final_shares_chg  new_shares    new_value  new_value_chg
# 0   555.878237             555.0     558.140  40409.33600       40182.00
# 1  2064.658741            2064.0    2613.871  80925.44616       63901.44
# 2   307.558930             307.0     458.578  80847.30140       54124.10
# 3  -203.553477            -203.0     311.298  81090.01602      -52879.47
# 4 -1467.713022           -1467.0     218.890  81210.37890     -544271.67
#
# [5 rows x 24 columns]

# %%
exec_port = rebal.build_execution_df(stable_port, rebal_port)
exec_port.head()
# Out:
#   ticker lastrebaldate assetclass  basisdate  costbasis    shares  \
# 0    HYG    2020-11-16        ETF 2018-11-16       85.0     3.140
# 1    IAU    2020-11-16        ETF 2018-11-16       18.0   549.871
# 2    IWM    2020-11-16        ETF 2018-11-16      157.0   151.578
# 3    QQQ    2020-11-16        ETF 2018-11-16      175.0   514.298
# 4    SPY    2020-11-16        ETF 2018-11-16      260.0  1685.890
#
#    allocation_target   close         value  allocation  correction  \
# 0               0.05   72.40     227.33600    0.000281    0.049719
# 1               0.10   30.96   17024.00616    0.021057    0.078943
# 2               0.10  176.30   26723.20140    0.033055    0.066945
# 3               0.10  260.49  133969.48602    0.165710   -0.065710
# 4               0.10  371.01  625482.04890    0.773673   -0.673673
#
#    new_money_in  rebal_flag  final_shares_chg  new_shares    new_value  \
# 0          50.0           1             555.0     558.140  40409.33600
# 1         100.0           1            2064.0    2613.871  80925.44616
# 2         100.0           1             307.0     458.578  80847.30140
# 3         100.0           1            -203.0     311.298  81090.01602
# 4         100.0           1           -1467.0     218.890  81210.37890
#
#    new_value_chg  final_allocation
# 0       40182.00          0.049923
# 1       63901.44          0.099979
# 2       54124.10          0.099882
# 3      -52879.47          0.100182
# 4     -544271.67          0.100331

# %%
import matplotlib.pyplot as plt
graph_port = exec_port[['ticker','allocation','allocation_target','final_allocation']].copy()
graph_port.plot.barh(x='ticker',figsize=(8,5))
plt.show()

# %%
port = rebal.merge_drift_and_execution(start_port, exec_port)
port.head()
# Out:
#   accounttype accountid ticker   shares assetclass   close         value  \
# 0         IRA      0003    HYG    3.140        ETF   72.40     227.33600
# 1         IRA      0003    IAU  549.871        ETF   30.96   17024.00616
# 2        401K      0002    IWM  151.578        ETF  176.30   26723.20140
# 3         IRA      0001    QQQ  514.298        ETF  260.49  133969.48602
# 4         IRA      0001    SPY  913.483        ETF  371.01  625482.04890
#
#    final_shares_chg  new_shares    new_value  new_value_chg  final_allocation  \
# 0             555.0     558.140  40409.33600       40182.00          0.049923
# 1            2064.0    2613.871  80925.44616       63901.44          0.099979
# 2             307.0     458.578  80847.30140       54124.10          0.099882
# 3            -203.0     311.298  81090.01602      -52879.47          0.100182
# 4           -1467.0     218.890  81210.37890     -544271.67          0.100331
#
#      value_orig  tick_alloc
# 0     227.33600     1.00000
# 1   17024.00616     1.00000
# 2   26723.20140     1.00000
# 3  133969.48602     1.00000
# 4  338911.32783     0.54184

# %%
port = rebal.catch_edge_cases(port)
port.head()
# Out:
#   accounttype accountid ticker   shares assetclass   close         value  \
# 0         IRA      0003    HYG    3.140        ETF   72.40     227.33600
# 1         IRA      0003    IAU  549.871        ETF   30.96   17024.00616
# 2        401K      0002    IWM  151.578        ETF  176.30   26723.20140
# 3         IRA      0001    QQQ  514.298        ETF  260.49  133969.48602
# 4         IRA      0001    SPY  913.483        ETF  371.01  338911.32783
#
#    final_shares_chg   new_shares    new_value  new_value_chg  final_allocation
# 0        555.000000   558.140000  40409.33600    40182.00000          0.049923
# 1       2064.000000  2613.871000  80925.44616    63901.44000          0.099979
# 2        307.000000   458.578000  80847.30140    54124.10000          0.099882
# 3       -203.000000   311.298000  81090.01602   -52879.47000          0.100182
# 4       -794.879595   118.603405  44003.04916  -294908.27867          0.054363

# %% [markdown]
# # Options

# %%
import pandas as pd
from yahoo_fin import options
import QuantLib as ql
import datetime
ql.__version__
# Out:
# '1.27'

# %%
ticker = 'XLF'
dates = options.get_expiration_dates(ticker)
chain = options.get_options_chain(ticker)
calls, puts = chain['calls'], chain['puts']
# calls

# %%
tickers = ['XLF', 'XLE', 'IVV', 'QQQ', 'IBB']
data = {}
date_select = pd.to_datetime(options.get_expiration_dates(ticker)[5], format = '%B %d, %Y').strftime('%m/%d/%Y')
print(date_select)
for ticker in tickers:
    try:
        data[ticker] = {
            'dates':options.get_expiration_dates(ticker),
            'chain':options.get_options_chain(ticker, date_select)
            }
    except Exception:
        print(ticker + " failed")
# Out:
# 12/09/2022

# %%
puts = data['XLF']['chain']['puts']
puts
# Out:
#          Contract Name         Last Trade Date  Strike  Last Price   Bid  \
# 0   XLF221209P00025000   2022-11-03 1:53PM EDT    25.0        0.01  0.00
# 1   XLF221209P00028500  2022-10-27 11:30AM EDT    28.5        0.14  0.06
# 2   XLF221209P00029000  2022-10-27 10:14AM EDT    29.0        0.14  0.08
# 3   XLF221209P00029500  2022-11-03 11:15AM EDT    29.5        0.15  0.11
# 4   XLF221209P00030000  2022-11-03 10:01AM EDT    30.0        0.22  0.17
# 5   XLF221209P00030500  2022-11-03 10:24AM EDT    30.5        0.26  0.21
# 6   XLF221209P00031500   2022-10-28 3:52PM EDT    31.5        0.34  0.35
# 7   XLF221209P00032000   2022-11-03 2:21PM EDT    32.0        0.50  0.49
# 8   XLF221209P00033000   2022-11-03 3:50PM EDT    33.0        0.87  0.81
# 9   XLF221209P00033500  2022-11-03 10:24AM EDT    33.5        1.14  1.02
# 10  XLF221209P00034000  2022-11-03 10:52AM EDT    34.0        1.33  1.23
#
#      Ask  Change % Change Volume  Open Interest Implied Volatility
# 0   0.04   -0.06  -85.71%      5              1             46.09%
# 1   0.10    0.00        -      -              1             33.11%
# 2   0.14    0.00        -      -             10             32.81%
# 3   0.16    0.04  +36.36%     11             12             30.76%
# 4   0.21    0.08  +57.14%     31             45             29.98%
# 5   0.27   -0.01   -3.70%     26              4             29.05%
# 6   0.47    0.00        -      6             14             28.03%
# 7   0.58    0.11  +28.21%    239             45             26.81%
# 8   0.94    0.33  +61.11%    217             13             25.73%
# 9   1.18    0.27  +31.03%     26              2             25.39%
# 10  1.54    0.31  +30.39%      5             14             27.05%

# %%
import yahoo_fin.stock_info as si
price = si.get_data("XLF")['close'].iloc[-1]
price
# Out:
# 33.29999923706055

# %%
contract = puts[puts['Contract Name']=='XLF221209P00031500']
contract
# Out:
#         Contract Name        Last Trade Date  Strike  Last Price   Bid   Ask  \
# 6  XLF221209P00031500  2022-10-28 3:52PM EDT    31.5        0.34  0.35  0.47
#
#    Change % Change Volume  Open Interest Implied Volatility
# 6     0.0        -      6             14             28.03%

# %%
date = pd.to_datetime(date_select)

maturity_date = ql.Date(date.day, date.month, date.year)
spot_price = price
strike_price = contract['Strike'].values[0]
volatility = float(contract['Implied Volatility'].values[0].replace('%',''))/100
dividend_rate =  0
option_type = ql.Option.Put

risk_free_rate = 0.04
day_count = ql.Actual365Fixed()
calendar = ql.UnitedStates()

today = datetime.datetime.today()
calculation_date = ql.Date(today.day, today.month,  today.year)
ql.Settings.instance().evaluationDate = calculation_date

# %%
payoff = ql.PlainVanillaPayoff(option_type, strike_price)
settlement = calculation_date

# %%
spot_handle = ql.QuoteHandle(
    ql.SimpleQuote(spot_price)
)
flat_ts = ql.YieldTermStructureHandle(
    ql.FlatForward(calculation_date, risk_free_rate, day_count)
)
dividend_yield = ql.YieldTermStructureHandle(
    ql.FlatForward(calculation_date, dividend_rate, day_count)
)
flat_vol_ts = ql.BlackVolTermStructureHandle(
    ql.BlackConstantVol(calculation_date, calendar, volatility, day_count)
)
bsm_process = ql.BlackScholesMertonProcess(spot_handle, 
                                           dividend_yield, 
                                           flat_ts, 
                                           flat_vol_ts)

# %%
am_exercise = ql.AmericanExercise(settlement, maturity_date)
american_option = ql.VanillaOption(payoff, am_exercise)
american_option
# Out:
# <QuantLib.QuantLib.VanillaOption; proxy of <Swig Object of type 'ext::shared_ptr< VanillaOption > *' at 0x000001E78E4E7CC0> >

# %%
steps = 200
binomial_engine = ql.BinomialVanillaEngine(bsm_process, "crr", steps)
american_option.setPricingEngine(binomial_engine)
american_option.NPV()
# Out:
# 0.42668196229966604

# %%
# from lib.derivatives.options.strategies import bull_call_spread as bcs
import numpy as np
import matplotlib.pyplot as plt
import seaborn

def call_payoff(sT, strike_price, premium):
    return np.where(sT > strike_price, sT - strike_price, 0) - premium

spot_price = 1130
strike_price_long_call = 1160
premium_long_call = 20
strike_price_short_call = 1200
premium_short_call = 11
sT = np.arange(0.95*spot_price,1.1*spot_price,1)


payoff_long_call = call_payoff(sT, strike_price_long_call, premium_long_call)
# Plot
fig, ax = plt.subplots()
ax.spines['bottom'].set_position('zero')
ax.plot(sT,payoff_long_call,label='Long 1160 Strike Call',color='g')
plt.xlabel('Infosys Stock Price')
plt.ylabel('Profit and loss')
plt.legend()
plt.show()


payoff_short_call = call_payoff(sT, strike_price_short_call, premium_short_call) * -1.0
# Plot
fig, ax = plt.subplots()
ax.spines['bottom'].set_position('zero')
ax.plot(sT,payoff_short_call,label='Short 1200 Strike Call',color='r')
plt.xlabel('Infosys Stock Price')
plt.ylabel('Profit and loss')
plt.legend()
plt.show()


payoff_bull_call_spread = payoff_long_call + payoff_short_call

print("Max Profit:", max(payoff_bull_call_spread))
print ("Max Loss:", min(payoff_bull_call_spread))
# Plot
fig, ax = plt.subplots()
ax.spines['bottom'].set_position('zero')
ax.plot(sT,payoff_long_call,'--',label='Long 1160 Strike Call',color='g')
ax.plot(sT,payoff_short_call,'--',label='Short 1200 Strike Call ',color='r')
ax.plot(sT,payoff_bull_call_spread,label='Bull Call Spread')
plt.xlabel('Infosys Stock Price')
plt.ylabel('Profit and loss')
plt.legend()
plt.show()
# Out:
# Max Profit: 31.0
# Max Loss: -9.0
