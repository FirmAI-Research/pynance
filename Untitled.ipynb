# %%
from enum import Enum
import sys, os
import nasdaqdatalink
import pandas as pd 
import numpy as np
from scipy.stats.mstats import gmean

# proj_root = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
# print(proj_root)
# sys.path.append(proj_root)


import nasdaq_data_link as nasdaq
from nasdaq_data_link import Sharadar
from numeric import custom_formatting
from calendar_dates import Calendar
from lib.equity.fundamentals import Fundamentals
cal = Calendar()
# Out:
# C:\dev\pynance\lib

# %%
# Fundamentals
fun = Fundamentals()
df_fun = fun.full_export(curl = False) # Set curl = True if data should be refreshed
print(df_fun)

# Static Profile info
nasdaq.Nasdaq()
tick = nasdaq.Tickers()
df_prof = tick.full_export()

all_industies = df_prof.industry.unique().tolist()
print(all_industies)

# Join
df = df_fun.set_index('ticker').merge(df_prof.set_index('ticker'), how='inner', left_index=True, right_index=True)
print(df)
# Out:
#        ticker dimension calendardate     datekey reportperiod lastupdated  \
# 0           A       ARQ   2017-03-31  2017-06-06   2017-04-30  2022-09-01
# 1           A       ARQ   2017-06-30  2017-09-06   2017-07-31  2022-09-01
# 2           A       ARQ   2017-09-30  2017-12-21   2017-10-31  2022-09-01
# 3           A       ARQ   2017-12-31  2018-03-06   2018-01-31  2022-09-01
# 4           A       ARQ   2018-03-31  2018-05-31   2018-04-30  2022-09-01
# ...       ...       ...          ...         ...          ...         ...
# 556311   ISRG       MRY   2017-12-31  2017-12-31   2017-12-31  2022-10-21
# 556312   ISRG       MRY   2018-12-31  2018-12-31   2018-12-31  2022-10-21
# 556313   ISRG       MRY   2019-12-31  2019-12-31   2019-12-31  2022-10-21
# 556314   ISRG       MRY   2020-12-31  2020-12-31   2020-12-31  2022-10-21
# 556315   ISRG       MRY   2021-12-31  2021-12-31   2021-12-31  2022-10-21
#
#              accoci        assets     assetsavg       assetsc  ...  \
# 0      -477000000.0  8.016000e+09           NaN  3.800000e+09  ...
# 1      -417000000.0  8.261000e+09           NaN  3.996000e+09  ...
# 2      -346000000.0  8.426000e+09           NaN  4.169000e+09  ...
# 3      -269000000.0  8.698000e+09           NaN  4.397000e+09  ...
# 4      -310000000.0  8.784000e+09           NaN  4.525000e+09  ...
# ...             ...           ...           ...           ...  ...
# 556311  -15500000.0  5.776800e+09  5.370050e+09  2.808900e+09  ...
# 556312  -13300000.0  7.846700e+09  7.110275e+09  4.333200e+09  ...
# 556313   12400000.0  9.733200e+09  8.907750e+09  4.662600e+09  ...
# 556314   24900000.0  1.116890e+10  1.044528e+10  6.625900e+09  ...
# 556315  -24200000.0  1.355500e+10  1.258175e+10  5.844900e+09  ...
#
#               p/cf  oppmargin     intcov  paoutratio   taxrate  \
# 0        90.244768   0.182396  10.550000    0.258824  0.141361
# 1       112.570217   0.180431  11.157895    0.240000  0.093264
# 2        94.826857   0.195963  12.300000    0.240000  0.216814
# 3       141.702450   0.197358  12.650000   -0.150505  2.373391
# 4        77.691904   0.178275  12.947368    0.232812  0.096916
# ...            ...        ...        ...         ...       ...
# 556311   42.898382   0.338697        inf    0.000000  0.392741
# 556312   55.683965   0.322056        inf    0.000000  0.120477
# 556313   58.264777   0.306911        inf    0.000000  0.080283
# 556314   84.118028   0.240868        inf    0.000000  0.116755
# 556315   73.941589   0.318909        inf    0.000000  0.086887
#
#         retentionratio  expnetincgrow  exproegrow  eqreinvestrate  expebitgrow
# 0            -0.023963            NaN    0.004650             NaN          NaN
# 1            -0.014857            NaN    0.002956             NaN          NaN
# 2            -0.007119            NaN    0.007795             NaN          NaN
# 3             0.016531            NaN    0.090066             NaN          NaN
# 4            -0.020098            NaN    0.003544             NaN          NaN
# ...                ...            ...         ...             ...          ...
# 556311        0.001714       0.000250    0.090797        0.001714     0.000241
# 556312        0.013491       0.002509    0.023133        0.013491     0.002278
# 556313        0.018085       0.003292    0.014570        0.018085     0.003019
# 556314        0.030750       0.003598    0.014407        0.030750     0.003351
# 556315        0.027930       0.004301    0.013629        0.027930     0.004000
#
# [556316 rows x 124 columns]
# ['Oil & Gas Drilling', 'Shell Companies', 'Specialty Industrial Machinery', 'Consulting Services', 'Gold', 'Electrical Equipment & Parts', 'REIT - Mortgage', 'Biotechnology', 'Software - Application', 'Oil & Gas E&P', 'Auto Manufacturers', 'Banks - Regional', 'Medical Devices', 'Insurance - Life', 'Communication Equipment', 'Restaurants', 'Diagnostics & Research', 'Specialty Business Services', 'Tobacco', 'Specialty Retail', 'Education & Training Services', 'Aerospace & Defense', 'Advertising Agencies', 'Internet Retail', 'Medical Instruments & Supplies', 'Real Estate Services', 'Recreational Vehicles', 'Farm Products', 'Credit Services', 'Oil & Gas Midstream', 'Entertainment', 'Household & Personal Products', 'Building Products & Equipment', 'Semiconductors', 'Medical Care Facilities', 'Oil & Gas Equipment & Services', 'Packaging & Containers', 'Other Industrial Metals & Mining', 'Banks - Diversified', 'Leisure', 'Scientific & Technical Instruments', 'Capital Markets', 'Software - Infrastructure', 'Drug Manufacturers - Specialty & Generic', 'Electronic Components', 'Health Information Services', 'Utilities - Renewable', 'Information Technology Services', 'Railroads', 'Internet Content & Information', 'Asset Management', 'Specialty Chemicals', 'Packaged Foods', 'REIT - Diversified', 'Footwear & Accessories', 'Security & Protection Services', 'Furnishings Fixtures & Appliances', 'Real Estate - Development', 'Beverages - Wineries & Distilleries', 'Marine Shipping', 'Pollution & Treatment Controls', 'REIT - Retail', 'REIT - Office', 'Apparel Retail', 'Rental & Leasing Services', 'Drug Manufacturers - General', 'Home Improvement Retail', 'Staffing & Employment Services', 'Healthcare Plans', 'Utilities - Regulated Water', 'Beverages - Non-Alcoholic', 'Telecom Services', 'Paper & Paper Products', 'Luxury Goods', 'Insurance - Specialty', 'Electronic Gaming & Multimedia', 'Personal Services', 'Electronics & Computer Distribution', 'Gambling', 'Industrial Distribution', 'Lodging', 'Computer Hardware', 'Airlines', 'Other Precious Metals & Mining', 'Grocery Stores', 'Utilities - Independent Power Producers', 'Insurance - Reinsurance', 'Copper', 'Beverages - Brewers', 'Agricultural Inputs', 'Pharmaceutical Retailers', 'Apparel Manufacturing', 'Auto & Truck Dealerships', 'Insurance - Diversified', 'Solar', 'Uranium', 'Chemicals', 'Trucking', 'Insurance - Property & Casualty', 'Oil & Gas Refining & Marketing', 'Consumer Electronics', 'Utilities - Diversified', 'REIT - Specialty', 'Mortgage Finance', 'Auto Parts', 'Insurance Brokers', 'Lumber & Wood Production', 'Travel Services', 'Engineering & Construction', 'Steel', 'Residential Construction', 'REIT - Residential', 'Farm & Heavy Construction Machinery', 'Metal Fabrication', 'Utilities - Regulated Electric', 'Tools & Accessories', 'Waste Management', 'Airports & Air Services', 'Semiconductor Equipment & Materials', nan, 'Business Equipment & Supplies', 'Utilities - Regulated Gas', 'Publishing', 'Discount Stores', 'Department Stores', 'Textile Manufacturing', 'Oil & Gas Integrated', 'Broadcasting', 'Confectioners', 'REIT - Industrial', 'Furnishings', 'Conglomerates', 'Financial Data & Stock Exchanges', 'Food Distribution', 'Medical Distribution', 'Building Materials', 'REIT - Hotel & Motel', 'Financial Conglomerates', 'Diversified Industrials', 'Thermal Coal', 'Resorts & Casinos', 'Integrated Freight & Logistics', 'REIT - Healthcare Facilities', 'Real Estate - Diversified', 'Aluminum', 'Computer Systems', 'Savings & Cooperative Banks', 'Drug Manufacturers - Major', 'Coking Coal', 'Industrial Metals & Minerals', 'Shipping & Ports', 'Silver', 'Infrastructure Operations']
#        dimension calendardate     datekey reportperiod lastupdated_x  \
# ticker
# A            ARQ   2017-03-31  2017-06-06   2017-04-30    2022-09-01
# A            ARQ   2017-06-30  2017-09-06   2017-07-31    2022-09-01
# A            ARQ   2017-09-30  2017-12-21   2017-10-31    2022-09-01
# A            ARQ   2017-12-31  2018-03-06   2018-01-31    2022-09-01
# A            ARQ   2018-03-31  2018-05-31   2018-04-30    2022-09-01
# ...          ...          ...         ...          ...           ...
# NaN          MRY   2021-12-31  2021-12-31   2021-12-31    2022-08-12
# NaN          ARQ   2022-06-30  2022-08-11   2022-06-30    2022-08-12
# NaN          ART   2022-06-30  2022-08-11   2022-06-30    2022-08-12
# NaN          MRQ   2022-06-30  2022-06-30   2022-06-30    2022-08-12
# NaN          MRT   2022-06-30  2022-06-30   2022-06-30    2022-08-12
#
#              accoci        assets    assetsavg       assetsc      assetsnc  \
# ticker
# A      -477000000.0  8.016000e+09          NaN  3.800000e+09  4.216000e+09
# A      -417000000.0  8.261000e+09          NaN  3.996000e+09  4.265000e+09
# A      -346000000.0  8.426000e+09          NaN  4.169000e+09  4.257000e+09
# A      -269000000.0  8.698000e+09          NaN  4.397000e+09  4.301000e+09
# A      -310000000.0  8.784000e+09          NaN  4.525000e+09  4.259000e+09
# ...             ...           ...          ...           ...           ...
# NaN      -2467327.0  9.098327e+08  485663112.0  8.934280e+08  1.640471e+07
# NaN      -1130435.0  8.061419e+08          NaN  7.435995e+08  6.254234e+07
# NaN      -1130435.0  8.061419e+08          NaN  7.435995e+08  6.254234e+07
# NaN      -1130435.0  8.061419e+08          NaN  7.435995e+08  6.254234e+07
# NaN      -1130435.0  8.061419e+08          NaN  7.435995e+08  6.254234e+07
#
#         ...  expebitgrow                      name  exchange      sector  \
# ticker  ...
# A       ...          NaN  AGILENT TECHNOLOGIES INC      NYSE  Healthcare
# A       ...          NaN  AGILENT TECHNOLOGIES INC      NYSE  Healthcare
# A       ...          NaN  AGILENT TECHNOLOGIES INC      NYSE  Healthcare
# A       ...          NaN  AGILENT TECHNOLOGIES INC      NYSE  Healthcare
# A       ...          NaN  AGILENT TECHNOLOGIES INC      NYSE  Healthcare
# ...     ...          ...                       ...       ...         ...
# NaN     ...     0.129186             NANO LABS LTD    NASDAQ  Technology
# NaN     ...          NaN             NANO LABS LTD    NASDAQ  Technology
# NaN     ...          NaN             NANO LABS LTD    NASDAQ  Technology
# NaN     ...          NaN             NANO LABS LTD    NASDAQ  Technology
# NaN     ...          NaN             NANO LABS LTD    NASDAQ  Technology
#
#                       industry  scalemarketcap  scalerevenue  famasector  \
# ticker
# A       Diagnostics & Research       5 - Large     5 - Large         NaN
# A       Diagnostics & Research       5 - Large     5 - Large         NaN
# A       Diagnostics & Research       5 - Large     5 - Large         NaN
# A       Diagnostics & Research       5 - Large     5 - Large         NaN
# A       Diagnostics & Research       5 - Large     5 - Large         NaN
# ...                        ...             ...           ...         ...
# NaN             Semiconductors       3 - Small      1 - Nano         NaN
# NaN             Semiconductors       3 - Small      1 - Nano         NaN
# NaN             Semiconductors       3 - Small      1 - Nano         NaN
# NaN             Semiconductors       3 - Small      1 - Nano         NaN
# NaN             Semiconductors       3 - Small      1 - Nano         NaN
#
#                            famaindustry  lastupdated_y
# ticker
# A       Measuring and Control Equipment     2022-09-01
# A       Measuring and Control Equipment     2022-09-01
# A       Measuring and Control Equipment     2022-09-01
# A       Measuring and Control Equipment     2022-09-01
# A       Measuring and Control Equipment     2022-09-01
# ...                                 ...            ...
# NaN                Electronic Equipment     2022-08-12
# NaN                Electronic Equipment     2022-08-12
# NaN                Electronic Equipment     2022-08-12
# NaN                Electronic Equipment     2022-08-12
# NaN                Electronic Equipment     2022-08-12
#
# [556191 rows x 132 columns]
# Index(['dimension', 'calendardate', 'datekey', 'reportperiod', 'lastupdated_x',
#        'accoci', 'assets', 'assetsavg', 'assetsc', 'assetsnc',
#        ...
#        'expebitgrow', 'name', 'exchange', 'sector', 'industry',
#        'scalemarketcap', 'scalerevenue', 'famasector', 'famaindustry',
#        'lastupdated_y'],
#       dtype='object', length=132)

# %%
df.columns.tolist()
# Out:
# ['dimension',
#  'calendardate',
#  'datekey',
#  'reportperiod',
#  'lastupdated_x',
#  'accoci',
#  'assets',
#  'assetsavg',
#  'assetsc',
#  'assetsnc',
#  'assetturnover',
#  'bvps',
#  'capex',
#  'cashneq',
#  'cashnequsd',
#  'cor',
#  'consolinc',
#  'currentratio',
#  'de',
#  'debt',
#  'debtc',
#  'debtnc',
#  'debtusd',
#  'deferredrev',
#  'depamor',
#  'deposits',
#  'divyield',
#  'dps',
#  'ebit',
#  'ebitda',
#  'ebitdamargin',
#  'ebitdausd',
#  'ebitusd',
#  'ebt',
#  'eps',
#  'epsdil',
#  'epsusd',
#  'equity',
#  'equityavg',
#  'equityusd',
#  'ev',
#  'evebit',
#  'evebitda',
#  'fcf',
#  'fcfps',
#  'fxusd',
#  'gp',
#  'grossmargin',
#  'intangibles',
#  'intexp',
#  'invcap',
#  'invcapavg',
#  'inventory',
#  'investments',
#  'investmentsc',
#  'investmentsnc',
#  'liabilities',
#  'liabilitiesc',
#  'liabilitiesnc',
#  'marketcap',
#  'ncf',
#  'ncfbus',
#  'ncfcommon',
#  'ncfdebt',
#  'ncfdiv',
#  'ncff',
#  'ncfi',
#  'ncfinv',
#  'ncfo',
#  'ncfx',
#  'netinc',
#  'netinccmn',
#  'netinccmnusd',
#  'netincdis',
#  'netincnci',
#  'netmargin',
#  'opex',
#  'opinc',
#  'payables',
#  'payoutratio',
#  'pb',
#  'pe',
#  'pe1',
#  'ppnenet',
#  'prefdivis',
#  'price',
#  'ps',
#  'ps1',
#  'receivables',
#  'retearn',
#  'revenue',
#  'revenueusd',
#  'rnd',
#  'roa',
#  'roe',
#  'roic',
#  'ros',
#  'sbcomp',
#  'sgna',
#  'sharefactor',
#  'sharesbas',
#  'shareswa',
#  'shareswadil',
#  'sps',
#  'tangibles',
#  'taxassets',
#  'taxexp',
#  'taxliabilities',
#  'tbvps',
#  'workingcapital',
#  'cogs',
#  'roc',
#  'fcfmargin',
#  'p/cf',
#  'oppmargin',
#  'intcov',
#  'paoutratio',
#  'taxrate',
#  'retentionratio',
#  'expnetincgrow',
#  'exproegrow',
#  'eqreinvestrate',
#  'expebitgrow',
#  'name',
#  'exchange',
#  'sector',
#  'industry',
#  'scalemarketcap',
#  'scalerevenue',
#  'famasector',
#  'famaindustry',
#  'lastupdated_y']

# %%
def calculate_percentile_rank(self, df, column=None):
    arr = pd.to_numeric(df[column]).dropna().values
    Q1, median, Q3 = np.percentile(arr, [25, 50, 75])
    IQR = Q3 - Q1

    loval = Q1 - 1.5 * IQR
    hival = Q3 + 1.5 * IQR

    wiskhi = np.compress(arr <= hival, arr)
    wisklo = np.compress(arr >= loval, arr)

    actual_hival = np.max(wiskhi)
    actual_loval = np.min(wisklo)

    outliers_high = np.compress(arr > actual_hival, arr)
    outliers_low = np.compress(arr < actual_loval, arr)
    outliers = [x for x in outliers_high ] + [y for y in outliers_low]

    Qs = [actual_loval, Q1, median, Q3, actual_hival]
    # print(arr)
    # print(Qs)
    return Qs, outliers
