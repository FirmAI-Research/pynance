# %%
from lib.fixed_income.rates.treasury_rates import TreasuryRates
import seaborn as sns
import numpy as np
import warnings
import matplotlib.pyplot as plt
import pandas as pd
import fredapi
warnings.filterwarnings('ignore')

# %%
tr = TreasuryRates()

# %%
tr.get()
# Out:
#           date  1 Month  2 Month  3 Month  6 Month  1 Year  2 Year  3 Year  \
# 0   2022-01-03     0.05     0.06     0.08     0.22    0.40    0.78    1.04
# 1   2022-01-04     0.06     0.05     0.08     0.22    0.38    0.77    1.02
# 2   2022-01-05     0.05     0.06     0.09     0.22    0.41    0.83    1.10
# 3   2022-01-06     0.04     0.05     0.10     0.23    0.45    0.88    1.15
# 4   2022-01-07     0.05     0.05     0.10     0.24    0.43    0.87    1.17
# ..         ...      ...      ...      ...      ...     ...     ...     ...
# 164 2022-08-29     2.45     2.75     2.97     3.32    3.43    3.42    3.45
# 165 2022-08-30     2.43     2.73     2.97     3.31    3.48    3.46    3.47
# 166 2022-08-31     2.40     2.72     2.96     3.32    3.50    3.45    3.46
# 167 2022-09-01     2.53     2.80     2.97     3.34    3.51    3.51    3.54
# 168 2022-09-02     2.49     2.79     2.94     3.33    3.47    3.40    3.44
#
#      5 Year  7 Year  10 Year  20 Year  30 Year
# 0      1.37    1.55     1.63     2.05     2.01
# 1      1.37    1.57     1.66     2.10     2.07
# 2      1.43    1.62     1.71     2.12     2.09
# 3      1.47    1.66     1.73     2.12     2.09
# 4      1.50    1.69     1.76     2.15     2.11
# ..      ...     ...      ...      ...      ...
# 164    3.27    3.21     3.12     3.50     3.25
# 165    3.27    3.22     3.11     3.49     3.23
# 166    3.30    3.25     3.15     3.53     3.27
# 167    3.39    3.36     3.26     3.64     3.37
# 168    3.30    3.29     3.20     3.61     3.35
#
# [169 rows x 13 columns]

# %% [markdown]
# # Absolute Daily Changes

# %%
df = tr.change_distribution()

categories = df.columns[1:]
categories = [*categories, categories[0]]

a, b, c = df.iloc[-1, 1:].abs(), df.iloc[-2, 1:].abs(), df.iloc[-3, 1:].abs()
a = [*a, a[0]]
b = [*b, b[0]]
c = [*c, c[0]]

label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(a))

plt.figure(figsize = (12,7))
plt.subplot(polar=True)
plt.plot(label_loc, a, label=df['date'].iloc[-1].date())
plt.plot(label_loc, b, label=df['date'].iloc[-2].date())
plt.plot(label_loc, c, label=df['date'].iloc[-3].date())
plt.title('Absolute Daily Change', size=20, y=1.05)

lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
plt.legend()
plt.show()

# %% [markdown]
# # Daily Changes

# %%
tr.change_distribution()
# Out:
#         date  1 Month  2 Month  3 Month  6 Month  1 Year  2 Year  3 Year  \
# 0 2022-08-23     0.01     0.00    -0.02    -0.02   -0.03   -0.03   -0.01
# 1 2022-08-24     0.01     0.02     0.02     0.07    0.06    0.07    0.05
# 2 2022-08-25     0.13     0.08     0.06    -0.03   -0.02   -0.01   -0.03
# 3 2022-08-26    -0.03    -0.01     0.01     0.01    0.03    0.02    0.03
# 4 2022-08-29     0.06     0.06     0.08     0.06    0.07    0.05    0.05
# 5 2022-08-30    -0.02    -0.02     0.00    -0.01    0.05    0.04    0.02
# 6 2022-08-31    -0.03    -0.01    -0.01     0.01    0.02   -0.01   -0.01
# 7 2022-09-01     0.13     0.08     0.01     0.02    0.01    0.06    0.08
# 8 2022-09-02    -0.04    -0.01    -0.03    -0.01   -0.04   -0.11   -0.10
#
#    5 Year  7 Year  10 Year  20 Year  30 Year
# 0    0.01    0.02     0.02     0.01     0.02
# 1    0.02    0.06     0.06     0.06     0.06
# 2   -0.05   -0.09    -0.08    -0.08    -0.07
# 3    0.05    0.03     0.01    -0.03    -0.04
# 4    0.07    0.07     0.08     0.06     0.04
# 5    0.00    0.01    -0.01    -0.01    -0.02
# 6    0.03    0.03     0.04     0.04     0.04
# 7    0.09    0.11     0.11     0.11     0.10
# 8   -0.09   -0.07    -0.06    -0.03    -0.02

# %% [markdown]
# # Periodic Changes (5, 10, 30, 90 days)

# %%
tr.periodic_nominal_changes()
# Out:
#   Change Since  1 Month  2 Month  3 Month  6 Month  1 Year  2 Year  3 Year  \
# 0   2022-08-29     0.04     0.04    -0.03     0.01    0.04   -0.02   -0.01
# 0   2022-08-22     0.22     0.19     0.12     0.10    0.15    0.08    0.08
# 0   2022-07-25     0.35     0.48     0.32     0.27    0.40    0.40    0.46
# 0   2022-04-27     2.12     2.16     2.12     1.94    1.50    0.82    0.69
#
#    5 Year  7 Year  10 Year  20 Year  30 Year
# 0    0.03    0.08     0.08     0.11     0.10
# 0    0.13    0.17     0.17     0.13     0.11
# 0    0.41    0.40     0.39     0.33     0.31
# 0    0.49    0.45     0.38     0.53     0.44

# %% [markdown]
# # Points in time

# %%
data = tr.point_in_time_curves().reset_index()
melt = data.melt(id_vars=['index'])
plt.figure(figsize = (20,5))
sns.lineplot(data = melt, x = 'index', y = 'value', hue = 'date')
# Out:
# <AxesSubplot:xlabel='index', ylabel='value'>

# %% [markdown]
# # 10s - 2s Spread

# %%
plt.figure(figsize = (20,5))

raw = tr.get()
spread = raw[['date','10 Year', '2 Year']]
spread['dif'] = spread['10 Year'] - spread['2 Year']
g = sns.lineplot(data=spread, x = 'date', y = 'dif')
plt.xticks(rotation=45)
plt.axhline(0, c='black')

# %%
fred = fredapi.Fred(api_key='ae9eac413fee6bc7cbe0747b78d0b32c')

# %%
# Moodys seasoned bond yields
credit_spreads = fred.get_series('AAA').to_frame().rename(columns={0:'AAA'}).merge( 
    fred.get_series('BAA').to_frame().rename(columns={0:'BAA'}), left_index=True, right_index=True).merge(
    fred.get_series('BAMLH0A0HYM2EY').to_frame().rename(columns={0:'HY'}), left_index=True, right_index=True)
credit_spreads.tail()
# Out:
#              AAA   BAA    HY
# 2022-03-01  3.43  4.29  5.46
# 2022-04-01  3.76  4.66  5.86
# 2022-06-01  4.24  5.27  7.03
# 2022-07-01  4.06  5.21  8.83
# 2022-08-01  4.07  5.15  7.51

# %%
melt = credit_spreads.reset_index().melt(id_vars=['index'])
melt

# %%
plt.figure(figsize = (20,5))

g = sns.lineplot(data=melt, x = 'index', y = 'value', hue = 'variable')
plt.xticks(rotation=45)
plt.axhline(0, c='black')

# %%
(credit_spreads.BAA - credit_spreads.AAA).iloc[-10:].to_frame()
# Out:
#                0
# 2021-09-01  0.70
# 2021-10-01  0.67
# 2021-11-01  0.66
# 2021-12-01  0.65
# 2022-02-01  0.72
# 2022-03-01  0.86
# 2022-04-01  0.90
# 2022-06-01  1.03
# 2022-07-01  1.15
# 2022-08-01  1.08

# %% [markdown]
# # Percent Change from a Year Ago (YoY)

# %%
inflation = fred.get_series('PCE').to_frame().rename(columns={0:'PCE'}).merge( 
    fred.get_series('PCEPILFE').to_frame().rename(columns={0:'PCEPILFE'}), left_index=True, right_index=True).merge( # Core PCE 
    fred.get_series('CPIAUCSL').to_frame().rename(columns={0:'CPIAUCSL'}), left_index=True, right_index=True).merge( # CPI 
    fred.get_series('CPILFESL').to_frame().rename(columns={0:'CPILFESL'}), left_index=True, right_index=True) # Core CPI

# %%
inflation_yoy = (inflation / inflation.shift(12)) -1
inflation_yoy.iloc[-10:].style.format("{:.2%}").background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_83f66_row0_col0, #T_83f66_row7_col3 {
#   background-color: #1d6cb1;
#   color: #f1f1f1;
# }
# #T_83f66_row0_col1, #T_83f66_row0_col2, #T_83f66_row0_col3, #T_83f66_row6_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_83f66_row1_col0, #T_83f66_row4_col1, #T_83f66_row5_col3, #T_83f66_row8_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_83f66_row1_col1 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_83f66_row1_col2 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_83f66_row1_col3 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_83f66_row2_col0 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_83f66_row2_col1 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_83f66_row2_col2 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_83f66_row2_col3 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_83f66_row3_col0 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# #T_83f66_row3_col1, #T_83f66_row5_col2 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_83f66_row3_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_83f66_row3_col3 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_83f66_row4_col0 {
#   background-color: #083674;
#   color: #f1f1f1;
# }
# #T_83f66_row4_col2 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_83f66_row4_col3 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_83f66_row5_col0 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_83f66_row5_col1 {
#   background-color: #08458a;
#   color: #f1f1f1;
# }
# #T_83f66_row6_col1 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_83f66_row6_col2 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_83f66_row6_col3 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_83f66_row7_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_83f66_row7_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_83f66_row7_col2 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_83f66_row8_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_83f66_row8_col1 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_83f66_row8_col3, #T_83f66_row9_col3 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_83f66_row9_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_83f66_row9_col1 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_83f66_row9_col2 {
#   background-color: #1460a8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_83f66">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83f66_level0_col0" class="col_heading level0 col0" >PCE</th>
#       <th id="T_83f66_level0_col1" class="col_heading level0 col1" >PCEPILFE</th>
#       <th id="T_83f66_level0_col2" class="col_heading level0 col2" >CPIAUCSL</th>
#       <th id="T_83f66_level0_col3" class="col_heading level0 col3" >CPILFESL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83f66_level0_row0" class="row_heading level0 row0" >2021-10-01 00:00:00</th>
#       <td id="T_83f66_row0_col0" class="data row0 col0" >12.12%</td>
#       <td id="T_83f66_row0_col1" class="data row0 col1" >4.19%</td>
#       <td id="T_83f66_row0_col2" class="data row0 col2" >6.24%</td>
#       <td id="T_83f66_row0_col3" class="data row0 col3" >4.59%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row1" class="row_heading level0 row1" >2021-11-01 00:00:00</th>
#       <td id="T_83f66_row1_col0" class="data row1 col0" >13.30%</td>
#       <td id="T_83f66_row1_col1" class="data row1 col1" >4.69%</td>
#       <td id="T_83f66_row1_col2" class="data row1 col2" >6.83%</td>
#       <td id="T_83f66_row1_col3" class="data row1 col3" >4.95%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row2" class="row_heading level0 row2" >2021-12-01 00:00:00</th>
#       <td id="T_83f66_row2_col0" class="data row2 col0" >12.88%</td>
#       <td id="T_83f66_row2_col1" class="data row2 col1" >4.89%</td>
#       <td id="T_83f66_row2_col2" class="data row2 col2" >7.10%</td>
#       <td id="T_83f66_row2_col3" class="data row2 col3" >5.48%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row3" class="row_heading level0 row3" >2022-01-01 00:00:00</th>
#       <td id="T_83f66_row3_col0" class="data row3 col0" >11.34%</td>
#       <td id="T_83f66_row3_col1" class="data row3 col1" >5.13%</td>
#       <td id="T_83f66_row3_col2" class="data row3 col2" >7.53%</td>
#       <td id="T_83f66_row3_col3" class="data row3 col3" >6.04%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row4" class="row_heading level0 row4" >2022-02-01 00:00:00</th>
#       <td id="T_83f66_row4_col0" class="data row4 col0" >13.17%</td>
#       <td id="T_83f66_row4_col1" class="data row4 col1" >5.31%</td>
#       <td id="T_83f66_row4_col2" class="data row4 col2" >7.91%</td>
#       <td id="T_83f66_row4_col3" class="data row4 col3" >6.42%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row5" class="row_heading level0 row5" >2022-03-01 00:00:00</th>
#       <td id="T_83f66_row5_col0" class="data row5 col0" >8.88%</td>
#       <td id="T_83f66_row5_col1" class="data row5 col1" >5.22%</td>
#       <td id="T_83f66_row5_col2" class="data row5 col2" >8.56%</td>
#       <td id="T_83f66_row5_col3" class="data row5 col3" >6.44%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row6" class="row_heading level0 row6" >2022-04-01 00:00:00</th>
#       <td id="T_83f66_row6_col0" class="data row6 col0" >8.24%</td>
#       <td id="T_83f66_row6_col1" class="data row6 col1" >4.90%</td>
#       <td id="T_83f66_row6_col2" class="data row6 col2" >8.22%</td>
#       <td id="T_83f66_row6_col3" class="data row6 col3" >6.13%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row7" class="row_heading level0 row7" >2022-05-01 00:00:00</th>
#       <td id="T_83f66_row7_col0" class="data row7 col0" >8.75%</td>
#       <td id="T_83f66_row7_col1" class="data row7 col1" >4.68%</td>
#       <td id="T_83f66_row7_col2" class="data row7 col2" >8.52%</td>
#       <td id="T_83f66_row7_col3" class="data row7 col3" >6.01%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row8" class="row_heading level0 row8" >2022-06-01 00:00:00</th>
#       <td id="T_83f66_row8_col0" class="data row8 col0" >8.60%</td>
#       <td id="T_83f66_row8_col1" class="data row8 col1" >4.81%</td>
#       <td id="T_83f66_row8_col2" class="data row8 col2" >9.00%</td>
#       <td id="T_83f66_row8_col3" class="data row8 col3" >5.91%</td>
#     </tr>
#     <tr>
#       <th id="T_83f66_level0_row9" class="row_heading level0 row9" >2022-07-01 00:00:00</th>
#       <td id="T_83f66_row9_col0" class="data row9 col0" >8.66%</td>
#       <td id="T_83f66_row9_col1" class="data row9 col1" >4.56%</td>
#       <td id="T_83f66_row9_col2" class="data row9 col2" >8.48%</td>
#       <td id="T_83f66_row9_col3" class="data row9 col3" >5.91%</td>
#     </tr>
#   </tbody>
# </table>
